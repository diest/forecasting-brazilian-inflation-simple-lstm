# %% [markdown]
# # Basics of the study

# %% [markdown]
# This study is based on [this article](https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/) from Jason Brownlee. The explanation is great and quite intuitive!

# %% [markdown]
# ## Importing essential libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras as keras

from sklearn.metrics import mean_squared_error, r2_score
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Importing series

# %% [markdown]
# ### General IPCA
# General IPCA stands for general extended national consumer prices index. Having an overview of it would be useful for better understanding what's in store for the models and then making some adjustments so it becomes easier to work with.

# %%
ipca_general = pd.read_csv('Data/IPCA-general.csv', sep=';', decimal=',')
ipca_general.columns = ['Date', 'Variation_Percentage', 'Dropme']
ipca_general = ipca_general.drop('Dropme', axis=1)
ipca_general = ipca_general.set_index('Date')
print(ipca_general.info(),'\n')
print(ipca_general.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 528 entries, 1980.01 to 2023.12
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Variation_Percentage  528 non-null    float64
# dtypes: float64(1)
# memory usage: 8.2+ KB
# None
#
#          Variation_Percentage
# Date
# 1980.01              6.615649
# 1980.02              4.616919
# 1980.03              6.038389
# 1980.04              5.286114
# 1980.05              5.702721

# %%
plt.figure(figsize=(10,5))
plt.title('Variation percentage of Brazilian inflation across time', fontsize=10)
plt.plot(ipca_general)
plt.xticks(range(0,len(ipca_general),int(len(ipca_general)/33)+1), rotation=90)
plt.show()

# %% [markdown]
# Percentage values scaling from 0 to 100 and beyond might not be particularly helpful for working with a machine learning model, so the series will be divided by 100.

# %%
ipca_general_raw = ipca_general.div(100)
plt.figure(figsize=(10,5))
plt.title('Variation tax of Brazilian inflation across time', fontsize=10)
plt.plot(ipca_general_raw)
plt.xticks(range(0,len(ipca_general_raw),int(len(ipca_general_raw)/33)+1), rotation=90)
plt.show()

# %% [markdown]
# Now the series can be properly worked with.

# %% [markdown]
# ### IPCA (food and beverages)
# The inflation of food and beverages might behave differently from general inflation overall, so it might be interesting to analyze it as well.

# %%
ipca_food = pd.read_csv('Data/IPCA-food.csv', sep=';', decimal=',')
ipca_food.columns = ['Date', 'Variation_Percentage', 'Dropme']
ipca_food = ipca_food.drop('Dropme', axis=1)
ipca_food = ipca_food.set_index('Date')
print(ipca_food.info(),'\n')
print(ipca_food.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 519 entries, 1980.10 to 2023.12
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Variation_Percentage  518 non-null    float64
# dtypes: float64(1)
# memory usage: 8.1+ KB
# None
#
#          Variation_Percentage
# Date
# 1980.10                  5.92
# 1980.11                 10.97
# 1980.12                  5.73
# 1981.01                  6.41
# 1981.02                  5.34

# %% [markdown]
# There's one missing value in the series, so it will be treated as the mean between the neighbor values.

# %%
plt.figure(figsize=(10,5))
plt.title('Variation percentage of Brazilian inflation for food and beverages across time', fontsize=10)
plt.plot(ipca_food)
plt.xticks(range(0,len(ipca_food),int(len(ipca_food)/33)+1), rotation=90)
plt.show()

# %% [markdown]
# The missing value is between 1991.06 and 1992.10, so it's important to look for it in this slice.

# %%
ipca_food['1991.06':'1992.10']
# Out:
#          Variation_Percentage
# Date
# 1991.06                 11.23
# 1991.07                 12.79
# 1991.08                   NaN
# 1991.09                 37.85
# 1991.10                 25.61
# 1991.11                 30.91
# 1991.12                 21.66
# 1992.01                 24.30
# 1992.02                 24.68
# 1992.03                 20.89
# 1992.04                 18.91
# 1992.05                 25.34
# 1992.06                 20.57
# 1992.07                 20.81
# 1992.08                 22.93
# 1992.09                 25.72
# 1992.10                 26.93

# %%
ipca_food_notnull = ipca_food.copy()
ipca_food_notnull = ipca_food_notnull.fillna((12.79+37.85)/2)
ipca_food_notnull['1991.06':'1992.10']
# Out:
#          Variation_Percentage
# Date
# 1991.06                 11.23
# 1991.07                 12.79
# 1991.08                 25.32
# 1991.09                 37.85
# 1991.10                 25.61
# 1991.11                 30.91
# 1991.12                 21.66
# 1992.01                 24.30
# 1992.02                 24.68
# 1992.03                 20.89
# 1992.04                 18.91
# 1992.05                 25.34
# 1992.06                 20.57
# 1992.07                 20.81
# 1992.08                 22.93
# 1992.09                 25.72
# 1992.10                 26.93

# %%
ipca_food_raw = ipca_food_notnull.div(100)
plt.figure(figsize=(10,5))
plt.title('Variation tax of Brazilian inflation for food and beverages across time', fontsize=10)
plt.plot(ipca_food_raw)
plt.xticks(range(0,len(ipca_food_raw),int(len(ipca_food_raw)/33)+1), rotation=90)
plt.show()

# %% [markdown]
# ### IPCA (health expenses)

# %%
ipca_health = pd.read_csv('Data/IPCA-health.csv', sep=';', decimal=',')
ipca_health.columns = ['Date', 'Variation_Percentage', 'Dropme']
ipca_health = ipca_health.drop('Dropme', axis=1)
ipca_health = ipca_health.set_index('Date')
print(ipca_health.info(),'\n')
print(ipca_health.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 519 entries, 1980.10 to 2023.12
# Data columns (total 1 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Variation_Percentage  518 non-null    float64
# dtypes: float64(1)
# memory usage: 8.1+ KB
# None
#
#          Variation_Percentage
# Date
# 1980.10                  5.90
# 1980.11                  4.43
# 1980.12                  3.93
# 1981.01                  4.38
# 1981.02                  4.62

# %%
plt.figure(figsize=(10,5))
plt.title('Variation percentage of Brazilian inflation for health expenses across time', fontsize=10)
plt.plot(ipca_health)
plt.xticks(range(0,len(ipca_health),int(len(ipca_health)/33)+1), rotation=90)
plt.show()

# %%
ipca_health['1991.06':'1992.10']
# Out:
#          Variation_Percentage
# Date
# 1991.06                  8.87
# 1991.07                 15.00
# 1991.08                   NaN
# 1991.09                 36.40
# 1991.10                 18.23
# 1991.11                 27.68
# 1991.12                 31.49
# 1992.01                 30.57
# 1992.02                 27.33
# 1992.03                 23.43
# 1992.04                 23.25
# 1992.05                 28.14
# 1992.06                 19.23
# 1992.07                 21.69
# 1992.08                 22.31
# 1992.09                 23.60
# 1992.10                 26.10

# %%
ipca_health_notnull = ipca_health.copy()
ipca_health_notnull = ipca_health_notnull.fillna((15.00+36.40)/2)
ipca_health_notnull['1991.06':'1992.10']
# Out:
#          Variation_Percentage
# Date
# 1991.06                  8.87
# 1991.07                 15.00
# 1991.08                 25.70
# 1991.09                 36.40
# 1991.10                 18.23
# 1991.11                 27.68
# 1991.12                 31.49
# 1992.01                 30.57
# 1992.02                 27.33
# 1992.03                 23.43
# 1992.04                 23.25
# 1992.05                 28.14
# 1992.06                 19.23
# 1992.07                 21.69
# 1992.08                 22.31
# 1992.09                 23.60
# 1992.10                 26.10

# %%
ipca_health_raw = ipca_health_notnull.div(100)
plt.figure(figsize=(10,5))
plt.title('Variation tax of Brazilian inflation for health expenses across time', fontsize=10)
plt.plot(ipca_health_raw)
plt.xticks(range(0,len(ipca_health_raw),int(len(ipca_health_raw)/33)+1), rotation=90)
plt.show()

# %% [markdown]
# # LSTM applications

# %% [markdown]
# ## Standard LSTM

# %% [markdown]
# ### Split method and model
# Each series must first be split in sequences of steps so they fit the LSTM format. The method used for Standard LSTM can also be used for a Stacked LSTM without any changes.
# Since the data is in months, the model itself will use 12 timesteps, assembling a batch of one year to predict the following month.

# %%
# The series must first be prepared to fit the type of LSTM.
# This method can be used for both Standard and Stacked LSTMs.
def split_standard(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
# This model will use 12 timesteps, one for each month in a year, and a single feature.
n_steps_std = 12
n_features_std = 1

lstm_std = keras.models.Sequential()
lstm_std.add(keras.layers.LSTM(50, activation='relu', input_shape=(n_steps_std, n_features_std)))
lstm_std.add(keras.layers.Dense(1))
lstm_std.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %% [markdown]
# ### General IPCA

# %%
X_IPCAgen_std, y_IPCAgen_std = split_standard(np.array(ipca_general_raw), n_steps_std)
# Reshape from [samples, timesteps] into [samples, timesteps, features]
X_IPCAgen_std = X_IPCAgen_std.reshape((X_IPCAgen_std.shape[0], X_IPCAgen_std.shape[1], n_features_std))

# Separating values in training, validation and testing
# 70% of the series will be used for testing
Xtrain_IPCAgen_std = X_IPCAgen_std[:int(len(X_IPCAgen_std)*0.7)]
ytrain_IPCAgen_std = y_IPCAgen_std[:int(len(y_IPCAgen_std)*0.7)]
# 20% of the series will be used for validation
Xval_IPCAgen_std = X_IPCAgen_std[int(len(X_IPCAgen_std)*0.7):int(len(X_IPCAgen_std)*0.9)]
yval_IPCAgen_std = y_IPCAgen_std[int(len(y_IPCAgen_std)*0.7):int(len(y_IPCAgen_std)*0.9)]
# 10% of the series will be used for testing
Xtest_IPCAgen_std = X_IPCAgen_std[int(len(X_IPCAgen_std)*0.9):]
ytest_IPCAgen_std = y_IPCAgen_std[int(len(y_IPCAgen_std)*0.9):]

# %%
lstm_std.fit(Xtrain_IPCAgen_std, ytrain_IPCAgen_std, validation_data=(Xval_IPCAgen_std, yval_IPCAgen_std),
             epochs=200, verbose=1)
# Out:
# Epoch 1/200
# WARNING:tensorflow:From C:\ProgramData\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 12/12 [==============================] - 1s 24ms/step - loss: 0.0232 - val_loss: 4.0955e-04
# Epoch 2/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0157 - val_loss: 0.0017
# Epoch 3/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0114 - val_loss: 0.0027
# Epoch 4/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0088 - val_loss: 9.4815e-04
# Epoch 5/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0062 - val_loss: 3.5276e-04
# Epoch 6/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0050 - val_loss: 1.3499e-05
# Epoch 7/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0048 - val_loss: 5.8876e-05
# Epoch 8/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 2.1274e-05
# Epoch 9/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0045 - val_loss: 1.6936e-05
# Epoch 10/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0043 - val_loss: 8.9264e-06
# Epoch 11/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0042 - val_loss: 9.7193e-06
# Epoch 12/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 9.6209e-06
# Epoch 13/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0041 - val_loss: 1.0313e-05
# Epoch 14/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0040 - val_loss: 1.6344e-04
# Epoch 15/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0040 - val_loss: 5.9297e-05
# Epoch 16/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0039 - val_loss: 2.1155e-05
# Epoch 17/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038 - val_loss: 4.8736e-05
# Epoch 18/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0037 - val_loss: 1.4762e-05
# Epoch 19/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036 - val_loss: 2.3824e-05
# Epoch 20/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 3.1548e-05
# Epoch 21/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035 - val_loss: 1.9663e-04
# Epoch 22/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0035 - val_loss: 1.9825e-05
# Epoch 23/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034 - val_loss: 1.9116e-05
# Epoch 24/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0033 - val_loss: 6.3417e-05
# Epoch 25/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 2.1520e-05
# Epoch 26/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0032 - val_loss: 9.3781e-05
# Epoch 27/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 3.8559e-05
# Epoch 28/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0031 - val_loss: 2.6864e-05
# Epoch 29/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0030 - val_loss: 8.3363e-06
# Epoch 30/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 1.9741e-05
# Epoch 31/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 9.1083e-05
# Epoch 32/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 8.8046e-06
# Epoch 33/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 8.9643e-06
# Epoch 34/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0027 - val_loss: 1.6301e-05
# Epoch 35/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 8.6665e-06
# Epoch 36/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 3.6424e-05
# Epoch 37/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 9.4382e-05
# Epoch 38/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 1.8141e-04
# Epoch 39/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 2.5005e-04
# Epoch 40/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 7.6014e-05
# Epoch 41/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 1.9823e-05
# Epoch 42/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 3.4904e-05
# Epoch 43/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0025 - val_loss: 6.6128e-04
# Epoch 44/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 1.4650e-05
# Epoch 45/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 1.2600e-04
# Epoch 46/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 1.5009e-05
# Epoch 47/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 7.2390e-06
# Epoch 48/200
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0021 - val_loss: 1.5931e-05
# Epoch 49/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 4.7158e-05
# Epoch 50/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 1.2425e-05
# Epoch 51/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 8.9615e-06
# Epoch 52/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0020 - val_loss: 3.4330e-05
# Epoch 53/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 4.3874e-05
# Epoch 54/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 2.2553e-04
# Epoch 55/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 1.7832e-05
# Epoch 56/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 7.6655e-05
# Epoch 57/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 1.9117e-04
# Epoch 58/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0028 - val_loss: 1.8911e-04
# Epoch 59/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 1.1280e-04
# Epoch 60/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 9.8555e-06
# Epoch 61/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 7.7009e-06
# Epoch 62/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0021 - val_loss: 5.3661e-04
# Epoch 63/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0022 - val_loss: 1.4594e-05
# Epoch 64/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 6.6442e-05
# Epoch 65/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 2.0358e-04
# Epoch 66/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0019 - val_loss: 8.7219e-05
# Epoch 67/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.2953e-04
# Epoch 68/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 1.1356e-04
# Epoch 69/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 1.0258e-04
# Epoch 70/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 7.9250e-06
# Epoch 71/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 2.2085e-05
# Epoch 72/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 1.0459e-04
# Epoch 73/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 2.3249e-04
# Epoch 74/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.2922e-05
# Epoch 75/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 1.6845e-05
# Epoch 76/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0019 - val_loss: 8.2383e-06
# Epoch 77/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 7.1859e-06
# Epoch 78/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0017 - val_loss: 4.3228e-05
# Epoch 79/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0016 - val_loss: 7.8154e-06
# Epoch 80/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 8.9602e-06
# Epoch 81/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0022 - val_loss: 3.6335e-05
# Epoch 82/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 3.3706e-04
# Epoch 83/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 7.9291e-05
# Epoch 84/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 2.5241e-04
# Epoch 85/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 3.4893e-05
# Epoch 86/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 2.9158e-05
# Epoch 87/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0014 - val_loss: 1.7026e-04
# Epoch 88/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0014 - val_loss: 1.0363e-04
# Epoch 89/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 1.2091e-04
# Epoch 90/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 4.2954e-04
# Epoch 91/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 9.7626e-04
# Epoch 92/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 3.2710e-04
# Epoch 93/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 1.7161e-04
# Epoch 94/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 1.2061e-05
# Epoch 95/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0014 - val_loss: 3.7039e-05
# Epoch 96/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 1.2664e-05
# Epoch 97/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 1.3350e-04
# Epoch 98/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 1.1607e-04
# Epoch 99/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0015 - val_loss: 1.5246e-04
# Epoch 100/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 4.7504e-05
# Epoch 101/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0020 - val_loss: 3.9223e-05
# Epoch 102/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0013 - val_loss: 2.2190e-04
# Epoch 103/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 8.3639e-06
# Epoch 104/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0014 - val_loss: 1.2522e-04
# Epoch 105/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 8.9444e-04
# Epoch 106/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0017 - val_loss: 2.9267e-04
# Epoch 107/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 3.6653e-05
# Epoch 108/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 8.3517e-06
# Epoch 109/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 7.8757e-05
# Epoch 110/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 8.2082e-06
# Epoch 111/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 7.8359e-06
# Epoch 112/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 7.7266e-06
# Epoch 113/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 4.3959e-05
# Epoch 114/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 4.6492e-05
# Epoch 115/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 2.1566e-05
# Epoch 116/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 7.8007e-06
# Epoch 117/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 8.7819e-06
# Epoch 118/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 7.5567e-05
# Epoch 119/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0017 - val_loss: 4.4298e-04
# Epoch 120/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 7.6468e-05
# Epoch 121/200
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0011 - val_loss: 1.5023e-04
# Epoch 122/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 9.7101e-05
# Epoch 123/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 1.5183e-05
# Epoch 124/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 1.0421e-05
# Epoch 125/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0011 - val_loss: 7.2313e-05
# Epoch 126/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 1.2224e-04
# Epoch 127/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0031 - val_loss: 9.1603e-06
# Epoch 128/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 9.2474e-06
# Epoch 129/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 2.2715e-04
# Epoch 130/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 1.1407e-04
# Epoch 131/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 1.7434e-05
# Epoch 132/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0013 - val_loss: 3.3241e-04
# Epoch 133/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0029 - val_loss: 8.8972e-05
# Epoch 134/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0026 - val_loss: 9.8473e-05
# Epoch 135/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0024 - val_loss: 4.9630e-05
# Epoch 136/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 2.1538e-04
# Epoch 137/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0023 - val_loss: 3.5934e-04
# Epoch 138/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0024 - val_loss: 3.4329e-04
# Epoch 139/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0026 - val_loss: 4.2816e-04
# Epoch 140/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 2.1950e-05
# Epoch 141/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 1.5050e-04
# Epoch 142/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0025 - val_loss: 3.2169e-05
# Epoch 143/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0029 - val_loss: 3.4892e-04
# Epoch 144/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 4.8533e-05
# Epoch 145/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0021 - val_loss: 7.7574e-06
# Epoch 146/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 1.5116e-04
# Epoch 147/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 2.4183e-05
# Epoch 148/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0016 - val_loss: 1.6557e-05
# Epoch 149/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 3.3180e-05
# Epoch 150/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 1.0255e-05
# Epoch 151/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 1.2400e-05
# Epoch 152/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 5.0948e-05
# Epoch 153/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 3.2261e-05
# Epoch 154/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 1.4656e-04
# Epoch 155/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0018 - val_loss: 1.8198e-05
# Epoch 156/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0013 - val_loss: 9.2369e-06
# Epoch 157/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0012 - val_loss: 2.1678e-05
# Epoch 158/200
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0012 - val_loss: 1.1759e-05
# Epoch 159/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 4.1966e-05
# Epoch 160/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 1.0398e-04
# Epoch 161/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 9.7550e-06
# Epoch 162/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.5694e-04 - val_loss: 3.1381e-05
# Epoch 163/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.9558e-04 - val_loss: 1.8691e-05
# Epoch 164/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 2.8647e-05
# Epoch 165/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 1.3296e-05
# Epoch 166/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 7.3292e-05
# Epoch 167/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.3572e-04 - val_loss: 2.4988e-05
# Epoch 168/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 4.5549e-05
# Epoch 169/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.9295e-04 - val_loss: 1.3422e-04
# Epoch 170/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.5970e-04 - val_loss: 3.0835e-05
# Epoch 171/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.1464e-04 - val_loss: 1.1901e-05
# Epoch 172/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.0450e-04 - val_loss: 5.3730e-05
# Epoch 173/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.0473e-04 - val_loss: 9.5598e-05
# Epoch 174/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.9268e-04 - val_loss: 1.4376e-05
# Epoch 175/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6877e-04 - val_loss: 1.5501e-04
# Epoch 176/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0010 - val_loss: 1.3490e-05
# Epoch 177/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.4124e-04 - val_loss: 1.3502e-05
# Epoch 178/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.4824e-04 - val_loss: 1.9261e-05
# Epoch 179/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - val_loss: 1.8749e-05
# Epoch 180/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.8383e-04 - val_loss: 3.8934e-04
# Epoch 181/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 1.5747e-04
# Epoch 182/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 8.0121e-06
# Epoch 183/200
# 12/12 [==============================] - 0s 6ms/step - loss: 9.5851e-04 - val_loss: 2.1117e-04
# Epoch 184/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 1.2578e-04
# Epoch 185/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0011 - val_loss: 5.3561e-05
# Epoch 186/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.7327e-04 - val_loss: 1.0246e-05
# Epoch 187/200
# 12/12 [==============================] - 0s 9ms/step - loss: 8.2931e-04 - val_loss: 5.1188e-05
# Epoch 188/200
# 12/12 [==============================] - 0s 7ms/step - loss: 8.4135e-04 - val_loss: 1.1231e-05
# Epoch 189/200
# 12/12 [==============================] - 0s 6ms/step - loss: 8.4511e-04 - val_loss: 1.1113e-05
# Epoch 190/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0015 - val_loss: 7.8616e-06
# Epoch 191/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0023 - val_loss: 4.6257e-05
# Epoch 192/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 9.0429e-06
# Epoch 193/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0018 - val_loss: 4.5273e-05
# Epoch 194/200
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0011 - val_loss: 7.3827e-05
# Epoch 195/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.9493e-04 - val_loss: 2.3122e-05
# Epoch 196/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0010 - val_loss: 9.6952e-06
# Epoch 197/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.2366e-04 - val_loss: 2.3321e-05
# Epoch 198/200
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0012 - val_loss: 3.7745e-05
# Epoch 199/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.6402e-04 - val_loss: 1.4866e-05
# Epoch 200/200
# 12/12 [==============================] - 0s 7ms/step - loss: 9.3095e-04 - val_loss: 1.7765e-04

# %%
plt.figure(figsize=(10,5))
plt.title('Inflation forecasting - Training set')
plt.plot(ytrain_IPCAgen_std, color='blue', label='True')
plt.plot(lstm_std.predict(Xtrain_IPCAgen_std), color='orange', label='Predicted')
plt.legend()
plt.show()
# Out:
# 12/12 [==============================] - 0s 2ms/step

# %%
plt.figure(figsize=(10,5))
plt.title('Inflation forecasting - Validation set')
plt.plot(yval_IPCAgen_std, color='blue', label='True')
plt.plot(lstm_std.predict(Xval_IPCAgen_std), color='orange', label='Predicted')
plt.legend()
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
plt.figure(figsize=(10,5))
plt.title('Inflation forecasting - Test set')
plt.plot(ytest_IPCAgen_std, color='blue', label='True')
plt.plot(lstm_std.predict(Xtest_IPCAgen_std), color='orange', label='Predicted')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
plt.figure(figsize=(10,5))
plt.title('Inflation forecasting - Full series')
plt.plot(y_IPCAgen_std, color='blue', label='True')
plt.plot(lstm_std.predict(X_IPCAgen_std), color='orange', label='Predicted')
plt.legend()
plt.show()
# Out:
# 17/17 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Stacked LSTM

# %% [markdown]
# ### General IPCA

# %% [markdown]
# ## CNN LSTM

# %% [markdown]
# ### General IPCA
